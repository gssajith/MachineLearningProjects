# %% [markdown]
# <a href="https://colab.research.google.com/github/gssajith/MachineLearningProjects/blob/main/NN/NNUsingTFKeras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

print(tf.__version__)
# Out:
# 2.15.0

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
xs = np.array([-1.0, 0.0, 1.,2.,3.,4.], dtype=float)
ys = np.array([-3.0, -1.0,1.0,3.,5.,7.], dtype=float)

# %%
model.fit(xs, ys, epochs=1000)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 1s 527ms/step - loss: 1.0327
# Epoch 2/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.9402
# Epoch 3/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.8648
# Epoch 4/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.8030
# Epoch 5/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.7518
# Epoch 6/1000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.7090
# Epoch 7/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6730
# Epoch 8/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6423
# Epoch 9/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6158
# Epoch 10/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5927
# Epoch 11/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5723
# Epoch 12/1000
# ...

# %%
model.predict([10.0])
# Out:
# 1/1 [==============================] - 0s 203ms/step
# array([[18.999922]], dtype=float32)
